# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaVutti/Idea_Validator-AI-Earth-Hack/blob/main/Idea_Validator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import chardet
def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']
file_path = 'Dataset.csv'
detected_encoding = detect_encoding(file_path)
data = pd.read_csv(file_path, encoding=detected_encoding)

# %%
data
# Out:
#         id                                            problem  \
# 0        1  The construction industry is indubitably one o...
# 1        2  I'm sure you, like me, are feeling the heat - ...
# 2        3  The massive shift in student learning towards ...
# 3        4  The fashion industry is one of the top contrib...
# 4        5  The majority of the materials used in producin...
# ...    ...                                                ...
# 1295  1296  The linear 'take, make, dispose' model of prod...
# 1296  1297  The conundrum we face is the improper disposal...
# 1297  1298             This solution will help the vegetation
# 1298  1299  Accumulation and improper disposal of single-u...
# 1299  1300  The excessive and wasteful resource consumptio...
#
#                                                solution
# 0     Herein, we propose an innovative approach to m...
# 1     Imagine standing on a green hill, not a single...
# ...

# %%
data['problem']=data['problem'].str.lower()
data['solution']=data['solution'].str.lower()
data.head()
# Out:
#    id                                            problem  \
# 0   1  the construction industry is indubitably one o...
# 1   2  i'm sure you, like me, are feeling the heat - ...
# 2   3  the massive shift in student learning towards ...
# 3   4  the fashion industry is one of the top contrib...
# 4   5  the majority of the materials used in producin...
#
#                                             solution
# 0  herein, we propose an innovative approach to m...
# 1  imagine standing on a green hill, not a single...
# 2  implement a ""book swap"" program within educa...
# 3  the proposed solution is a garment rental serv...
# 4  an innovative concept would be a modular elect...

# %% [markdown]
# ##Removing puctuation

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuations(text):
    punctuations = string.punctuation
    return text.translate(str.maketrans('', '', punctuations))

# %%
data['problem'] = data['problem'].apply(lambda x: remove_punctuations(x))
data.head()
# Out:
#    id                                            problem  \
# 0   1  the construction industry is indubitably one o...
# 1   2  im sure you like me are feeling the heat  lite...
# 2   3  the massive shift in student learning towards ...
# 3   4  the fashion industry is one of the top contrib...
# 4   5  the majority of the materials used in producin...
#
#                                             solution
# 0  herein, we propose an innovative approach to m...
# 1  imagine standing on a green hill, not a single...
# 2  implement a ""book swap"" program within educa...
# 3  the proposed solution is a garment rental serv...
# 4  an innovative concept would be a modular elect...

# %%
data['solution'] = data['solution'].astype(str).apply(lambda x: remove_punctuations(x))
data.head()
# Out:
#    id                                            problem  \
# 0   1  the construction industry is indubitably one o...
# 1   2  im sure you like me are feeling the heat  lite...
# 2   3  the massive shift in student learning towards ...
# 3   4  the fashion industry is one of the top contrib...
# 4   5  the majority of the materials used in producin...
#
#                                             solution
# 0  herein we propose an innovative approach to mi...
# 1  imagine standing on a green hill not a single ...
# 2  implement a book swap program within education...
# 3  the proposed solution is a garment rental serv...
# 4  an innovative concept would be a modular elect...

# %% [markdown]
# ##Removal of Stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
", ".join(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in STOPWORDS])

# %%
data['problem'] = data['problem'].apply(lambda x: remove_stopwords(x))
data['solution'] = data['solution'].astype(str).apply(lambda x: remove_stopwords(x))
data.head()
# Out:
#    id                                            problem  \
# 0   1  construction industry indubitably one signific...
# 1   2  im sure like feeling heat literally world heal...
# 2   3  massive shift student learning towards digital...
# 3   4  fashion industry one top contributors global p...
# 4   5  majority materials used producing electronic g...
#
#                                             solution
# 0  herein propose innovative approach mitigate pr...
# 1  imagine standing green hill single towering no...
# 2  implement book swap program within educational...
# 3  proposed solution garment rental service servi...
# 4  innovative concept would modular electronic de...

# %% [markdown]
# ##Removal of Special characters

# %%
import re
def remove_spl_chars(text):
    text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = re.sub('\s+', ' ', text)
    return text

# %%
data['problem'] = data['problem'].apply(lambda x: remove_spl_chars(x))
data['solution'] = data['solution'].astype(str).apply(lambda x: remove_spl_chars(x))
data.head()
# Out:
#    id                                            problem  \
# 0   1  construction industry indubitably one signific...
# 1   2  im sure like feeling heat literally world heal...
# 2   3  massive shift student learning towards digital...
# 3   4  fashion industry one top contributors global p...
# 4   5  majority materials used producing electronic g...
#
#                                             solution
# 0  herein propose innovative approach mitigate pr...
# 1  imagine standing green hill single towering no...
# 2  implement book swap program within educational...
# 3  proposed solution garment rental service servi...
# 4  innovative concept would modular electronic de...

# %% [markdown]
# ##Lemmatization & POS Tagging

# %%
# !pip install nltk
# !nltk download wordnet
# Out:
# ...
# Usage: nltk [OPTIONS] COMMAND [ARGS]...
# Try 'nltk -h' for help.
#
# Error: No such command 'download'.

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}
def lemmatize_words(text):
    pos_text = pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_text])
wordnet.NOUN
# Out:
# 'n'

# %%
data['problem'] = data['problem'].apply(lambda x: lemmatize_words(x))
data['solution'] = data['solution'].astype(str).apply(lambda x: lemmatize_words(x))
data.head()
# Out:
#    id                                            problem  \
# 0   1  construction industry indubitably one signific...
# 1   2  im sure like feel heat literally world health ...
# 2   3  massive shift student learn towards digital pl...
# 3   4  fashion industry one top contributor global po...
# 4   5  majority material use produce electronic good ...
#
#                                             solution
# 0  herein propose innovative approach mitigate pr...
# 1  imagine stand green hill single tower noisy wi...
# 2  implement book swap program within educational...
# 3  propose solution garment rental service servic...
# 4  innovative concept would modular electronic de...

# %%
data.sample(frac=1).head(10)
# Out:
#         id                                            problem  \
# 265    266  increase level co2 greenhouse gas primarily re...
# 507    508  rapid depletion earth natural resource due uns...
# 466    467  solution offer broad scope tackle numerous sus...
# 538    539  product meant support electronic company suppo...
# 51      52                                  plastic recycling
# 939    940  many business food beverage industry produce s...
# 1251  1252  fashion industry one big contributor environme...
# 267    268  solution mean solve energy crisis problem well...
# 783    784  everincreasing generation electronic waste ewa...
# 855    856  fashion industry one polluting wastegenerating...
#
#                                                solution
# 265   propose innovative costefficient exhaust filte...
# 507   implement resource recycle management system i...
# 466   conundrum hand sequential course production co...
# 538   help increase quality companys productivitycap...
# ...

# %% [markdown]
# ##Removal of rare words

# %%
from collections import Counter
word_count = Counter()
for text in data['problem']:
    for word in text.split():
        word_count[word] += 1

# %%
word_count.most_common(10)
# Out:
# [('waste', 1283),
#  ('environmental', 666),
#  ('industry', 454),
#  ('resource', 437),
#  ('use', 393),
#  ('contribute', 369),
#  ('plastic', 365),
#  ('significant', 340),
#  ('pollution', 330),
#  ('problem', 318)]

# %%
RARE_WORDS = set(word for (word, wc) in word_count.most_common()[:-10:-1])
RARE_WORDS
# Out:
# {'commercialindustrial',
#  'conundrum',
#  'domestic',
#  'hash',
#  'possibly',
#  'sanction',
#  'shot',
#  'shrink',
#  'vastly'}

# %%
def remove_rare_words(text):
    return " ".join([word for word in text.split() if word not in RARE_WORDS])

# %%
data['solution'] = data['solution'].apply(lambda x: remove_rare_words(x))
data.head()
# Out:
#    id                                            problem  \
# 0   1  construction industry indubitably one signific...
# 1   2  im sure like feel heat literally world health ...
# 2   3  massive shift student learn towards digital pl...
# 3   4  fashion industry one top contributor global po...
# 4   5  majority material use produce electronic good ...
#
#                                             solution
# 0  herein propose innovative approach mitigate pr...
# 1  imagine stand green hill single tower noisy wi...
# 2  implement book swap program within educational...
# 3  propose solution garment rental service servic...
# 4  innovative concept would modular electronic de...

# %% [markdown]
# ## Idea Validator

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

problems = []
solutions = []

print("Enter problem statements to check feasibility.")
problem_input = input("Enter a problem statement:\n")
problems.append(problem_input)

print("\nEnter solutions for above problem statements.")
solution_input = input("Enter a solution:\n")
solutions.append(solution_input)

vectorizer = TfidfVectorizer()
problem_vectors = vectorizer.fit_transform(problems)
solution_vectors = vectorizer.transform(solutions)

similarity_scores = cosine_similarity(problem_vectors, solution_vectors)

threshold = 0.7
print("\n")

for i, problem in enumerate(problems):
    for j, solution in enumerate(solutions):
        if similarity_scores[i, j] > threshold:
            print(f"Feasible (Similarity Score: {similarity_scores[i, j]:.4f})\n")
        else:
            print(f"Infeasible (Similarity Score: {similarity_scores[i, j]:.4f})\n")
# Out:
# Enter problem statements to check feasibility.
# Enter a problem statement:
# Rapid advancement in technology and our demand for the latest electronic devices, such as laptops, computers, and other digital gadgets, result in huge amounts of electronic waste. It's not just harmful for the environment but also poses potential health risks due to the toxic materials contained in these gadgets.
#
# Enter solutions for above problem statements.
# Enter a solution:
# ...

# %%
def idea_validator(solutions):
    feasibility_score = 0

    # Criteria 1: Idea clarity and specificity
    if len(solutions) > 0:
        feasibility_score += 1
    else:
        print("Idea is not clearly defined. Please provide a more specific description.")

    # Criteria 2: Potential target audience or users
    target_audience = input("Who is the target audience for this idea? ")
    if len(target_audience) > 0:
        feasibility_score += 1
    else:
        print("Target audience is not defined. Consider identifying potential users.")

    # Criteria 3: Value proposition
    value_proposition = input("What is the value proposition of the idea? ")
    if len(value_proposition) > 0:
        feasibility_score += 1
    else:
        print("Value proposition is not clear. Define the unique value your idea provides.")


    # Display feasibility assessment
    print("\nFeasibility Assessment:")
    if feasibility_score >= 5:
        print("The idea appears to be feasible.")
    else:
        print("The idea may require further refinement. Consider addressing the highlighted areas.")

if __name__ == "__main__":
    # Get idea input from the user
    user_idea = solutions

    # Validate the idea
    idea_validator(user_idea)
# Out:
# Who is the target audience for this idea? business companies
# What is the value proposition of the idea? 12,00,000
#
# Feasibility Assessment:
# The idea may require further refinement. Consider addressing the highlighted areas.

# %%
if similarity_scores[i, j] >= 0.7 and feasibility_score >= 5:
  print("Idea is feasible.")
else:
  print("Improvement needed to make the solution more feasible.")
# Out:
# Improvement needed to make the solution more feasible.
